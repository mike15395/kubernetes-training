# %% [markdown]
# kubectl create configmap --help

# %% [markdown]
# kubectl create configmap <map-name> <data-source>
# map-name is the configmap name and data-source is the directory,file or from literal values

# %% [markdown]
# ## kubectl create namespace configmap-test

# %% [markdown]
# # kubectl create configmap singlevalue-map --from-literal=partner-
# url=https://www.auppost.com.au --namespace configmap-test

# %% [markdown]
# # kubectl get configmaps --namespace configmap-test

# %% [markdown]
# ###kubectl get configmap singlevalue-map -o yaml --namespace configmap-
# test
